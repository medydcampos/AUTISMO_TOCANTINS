# %% [markdown]
# # Plotando gráficos
#
# Notebook para visualizar estatisticas descritivas da base `dados_limpos_breakdown.csv`.

# %%
from functions import (
    plotar_estatisticas_descritivas,
    plotar_histograma_matriculas,
    plotar_tendencia,
    plotar_crescimento_deficiencias,
)

# %% [markdown]
# ## Estatísticas descritivas

# %%
plotar_estatisticas_descritivas(
    "TEA_Autismo",
    plot="compara_anos",
    anos=[2021, 2022, 2023, 2024, 2025],
    dependencia_administrativa_breakdown=["Estadual"],
    extracao=True,
)

## a categoria "privado" não existe para 2023
# Out:
# ### TEA_Autismo - comparacao entre anos
#                        2021   2022   2023   2024   2025
# Municipios              136    136    136    137    137
# Total                   633    724    946  1.958  1.427
# Media                  4,65   5,32   6,96  14,29  10,42
# Desvio padrao         13,69  16,30  22,11  45,63  32,64
# Minimo                    0      0      0      0      0
# P25                       0      0      1      2      2
# Mediana                   1   1,50      2      4      3
# P75                       4   4,25   5,25     11      7
# Maximo                  136    168    233    488    330
# Assimetria             7,40   8,00   8,42   8,73   7,77
# Curtose               65,22  75,44  82,59  87,30  70,32
# Municipios com zero      43     37     33     25     10
# Municipios com valor     93     99    103    112    127
# **Nota interpretativa:** a curtose/kurtosis reportada e o excesso de curtose calculado pelo pandas; uma distribuicao normal tem valor proximo de 0.
#
# - 2021: Assimetria = 7,40 (positiva forte; distribuicao assimetrica a direita, com cauda alongada para valores mais altos.) Curtose/kurtosis = 65,22 (elevada; distribuicao leptocurtica, com caudas mais pesadas que a normal e maior presenca de valores extremos.)
# - 2022: Assimetria = 8,00 (positiva forte; distribuicao assimetrica a direita, com cauda alongada para valores mais altos.) Curtose/kurtosis = 75,44 (elevada; distribuicao leptocurtica, com caudas mais pesadas que a normal e maior presenca de valores extremos.)
# - 2023: Assimetria = 8,42 (positiva forte; distribuicao assimetrica a direita, com cauda alongada para valores mais altos.) Curtose/kurtosis = 82,59 (elevada; distribuicao leptocurtica, com caudas mais pesadas que a normal e maior presenca de valores extremos.)
# - 2024: Assimetria = 8,73 (positiva forte; distribuicao assimetrica a direita, com cauda alongada para valores mais altos.) Curtose/kurtosis = 87,30 (elevada; distribuicao leptocurtica, com caudas mais pesadas que a normal e maior presenca de valores extremos.)
# - 2025: Assimetria = 7,77 (positiva forte; distribuicao assimetrica a direita, com cauda alongada para valores mais altos.) Curtose/kurtosis = 70,32 (elevada; distribuicao leptocurtica, com caudas mais pesadas que a normal e maior presenca de valores extremos.)
# Tabela ABNT salva em: /Users/MaluEconomista/Documents/SIMONE_DISS/OUTPUT/tabela_abnt_compara_anos_tea_autismo_2021_2022_2023_2024_2025.html
# (                            2021        2022        2023         2024  \
#  Municipios            136.000000  136.000000  136.000000   137.000000
#  Total                 633.000000  724.000000  946.000000  1958.000000
#  Media                   4.654412    5.323529    6.955882    14.291971
#  Desvio padrao          13.690970   16.296731   22.109448    45.633959
#  Minimo                  0.000000    0.000000    0.000000     0.000000
#  P25                     0.000000    0.000000    1.000000     2.000000
#  Mediana                 1.000000    1.500000    2.000000     4.000000
#  P75                     4.000000    4.250000    5.250000    11.000000
#  Maximo                136.000000  168.000000  233.000000   488.000000
#  Assimetria              7.397557    8.003314    8.422403     8.727476
#  Curtose                65.224577   75.438465   82.591187    87.299671
#  Municipios com zero    43.000000   37.000000   33.000000    25.000000
#  Municipios com valor   93.000000   99.000000  103.000000   112.000000
#
#                               2025
#  Municipios             137.000000
#  Total                 1427.000000
#  Media                   10.416058
#  Desvio padrao           32.641016
#  Minimo                   0.000000
#  P25                      2.000000
#  Mediana                  3.000000
#  P75                      7.000000
#  Maximo                 330.000000
#  Assimetria               7.774454
#  Curtose                 70.316339
#  Municipios com zero     10.000000
#  Municipios com valor   127.000000  ,
#  None)

# %% [markdown]
# ## Tendência temporal

# %%
plotar_tendencia(
    deficiencia="TEA_Autismo",
    anos=[2021, 2022, 2023, 2024, 2025],
    zona_breakdown="Total",
    dependencia_administrativa_breakdown="Estadual",
    titulo="Matrículas de TEA/Autismo na rede estadual (2021–2025)",
    save_path="tendencia_tea_estadual_2021_2025.png",
)
# Out:
# Imagem salva em: /Users/MaluEconomista/Documents/SIMONE_DISS/OUTPUT/tendencia_tea_estadual_2021_2025.png
# (    Ano  Matriculas  Municipios
#  0  2021         633         136
#  1  2022         724         136
#  2  2023         946         136
#  3  2024        1958         137
#  4  2025        1427         137,
#  <Figure size 840x480 with 1 Axes>)

# %% [markdown]
# ## PLOTANDO HISTOGRAMAS

# %%
plotar_histograma_matriculas(
    deficiencia="TEA_Autismo",
    ano=2025,
    zona_breakdown="Total",
    dependencia_administrativa_breakdown="Estadual",
    titulo="Distribuição de matrículas de TEA/Autismo — rede estadual (2025)",
    bin_width=5,
    xlim_max=40,
    save_path="histograma_autismo_estadual_2025.png",
    densidade=True,
)
# Out:
# Imagem salva em: /Users/MaluEconomista/Documents/SIMONE_DISS/OUTPUT/histograma_autismo_estadual_2025.png
# Recorte visual: 0–40 matriculas. 5 municipio(s) acima desse limite (330, 141, 106, 78, 70) permanecem na amostra e no calculo da densidade.
# (                Municipio  Matriculas
#  0             Abreulândia           1
#  1           Aguiarnópolis           2
#  2    Aliança do Tocantins           4
#  3                   Almas           5
#  4                Alvorada           6
#  ..                    ...         ...
#  132            Tocantínia           4
#  133              Tupirama           2
#  134            Tupiratins           1
#  135          Wanderlândia           7
#  136               Xambioá           5
#
#  [137 rows x 2 columns],
#  <Figure size 800x500 with 1 Axes>)

# %% [markdown]
# ## Crescimento acumulado: TEA vs demais deficiências
#
# Variação relativa ponta a ponta \((X_{2025}-X_{2021})/X_{2021}\). A linha tracejada é a **cesta** das demais deficiências (crescimento da soma; exclui Visão Monocular, ausente em 2021–2022).

# %%
plotar_crescimento_deficiencias(
    deficiencia_destaque="TEA_Autismo",
    ano_inicial=2021,
    ano_final=2025,
    zona_breakdown="Total",
    dependencia_administrativa_breakdown="Estadual",
    titulo="Crescimento acumulado das matrículas por deficiência (rede estadual, 2021–2025)",
    save_path="crescimento_tea_vs_demais_2021_2025.png",
)
# Out:
# Imagem salva em: /Users/MaluEconomista/Documents/SIMONE_DISS/OUTPUT/crescimento_tea_vs_demais_2021_2025.png
# TEA/Autismo: 125,43% | Cesta demais: -37,93% (Diferença: 163,36 p.p.). Rede Estadual, Zona Total. Exclui Visao Monocular.
# (                      Deficiencia             Rotulo  Matriculas_2021  \
#  0                          Surdez             Surdez              119
#  1                   Surdocegueira      Surdocegueira                5
#  2            Deficiencia_Auditiva      Def. auditiva              295
#  3                     Baixa_Visao        Baixa visão              629
#  4                        Cegueira           Cegueira               41
#  5              Deficiencia_Fisica        Def. física              942
#  6         Deficiencia_Intelectual   Def. intelectual             7107
#  7            Deficiencia_Multipla      Def. múltipla              902
#  8                     TEA_Autismo        TEA/Autismo              633
#  9  Altas_Habilidades_Superdotacao  Altas habilidades               37
#
#     Matriculas_2025  Crescimento_pct  Destaque
#  0               52       -56.302521     False
#  1                1       -80.000000     False
#  2              142       -51.864407     False
#  3              444       -29.411765     False
#  4               26       -36.585366     False
#  5              447       -52.547771     False
#  6             4783       -32.700155     False
#  7              318       -64.745011     False
#  8             1427       125.434439      True
#  9               42        13.513514     False  ,
#  {'crescimento_destaque_pct': 125.434439178515,
#   'crescimento_cesta_pct': np.float64(-37.92795474843704),
#   'diferenca_pp': np.float64(163.36239392695205),
#   'matriculas_cesta_inicial': 10077.0,
#   'matriculas_cesta_final': 6255.0},
#  <Figure size 920x560 with 1 Axes>)
